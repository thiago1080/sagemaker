# %% [markdown]
# ## Train a model with bike rental data using XGBoost algorithm
# ###  Model is trained with XGBoost installed in notebook instance
# ###  In the later examples, we will train using SageMaker's XGBoost algorithm

# %%
# Install xgboost in notebook instance.
#### Command to install xgboost
# !pip install xgboost==0.90
# Out:
# Collecting xgboost==0.90
#   Downloading xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8 MB)
#      |████████████████████████████████| 142.8 MB 103 kB/s  eta 0:00:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==0.90) (1.19.5)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==0.90) (1.5.3)
# Installing collected packages: xgboost
# Successfully installed xgboost-0.90

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# XGBoost 
import xgboost as xgb

# %%
column_list_file = 'bike_train_column_list.txt'
train_file = 'bike_train.csv'
validation_file = 'bike_validation.csv'
test_file = 'bike_test.csv'

# %%
columns = ''
with open(column_list_file,'r') as f:
    columns = f.read().split(',')

# %%
columns
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'temp',
#  'atemp',
#  'humidity',
#  'windspeed',
#  'year',
#  'month',
#  'day',
#  'dayofweek',
#  'hour']

# %%
# Specify the column names as the file does not have column header
df_train = pd.read_csv(train_file,names=columns)
df_validation = pd.read_csv(validation_file,names=columns)

# %%
df_train.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0     87       3        0           0        2  26.24  30.305        73
# 1    248       3        0           1        1  32.80  34.850        33
# 2    334       4        0           0        1  15.58  19.695        40
# 3    623       3        0           1        1  32.80  37.880        55
# 4     70       2        0           1        1  13.94  17.425        76
#
#    windspeed  year  month  day  dayofweek  hour
# 0     7.0015  2011      9    3          5     0
# 1     7.0015  2012      8   13          0    14
# 2    11.0014  2011     11    5          5    17
# 3    12.9980  2012      8    9          3    19
# 4     7.0015  2011      4   14          3     6

# %%
df_validation.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0    443       3        0           1        2  28.70  33.335        79
# 1    387       2        0           0        1  32.80  37.880        55
# 2      2       1        0           1        1  14.76  16.665        40
# 3     48       1        0           1        1   9.02   9.090        47
# 4     55       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
X_train = df_train.iloc[:,1:] # Features: 1st column onwards 
y_train = df_train.iloc[:,0].ravel() # Target: 0th column

X_validation = df_validation.iloc[:,1:]
y_validation = df_validation.iloc[:,0].ravel()

# %%
# XGBoost Training Parameter Reference: 
#   https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
#regressor = xgb.XGBRegressor(max_depth=5,eta=0.1,subsample=0.7,num_round=150)
regressor = xgb.XGBRegressor(max_depth=5,n_estimators=150)

# %%
regressor
# Out:
# XGBRegressor(max_depth=5, n_estimators=150)

# %%
regressor.fit(X_train,y_train, eval_set = [(X_train, y_train), (X_validation, y_validation)])
# Out:
# [18:30:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:242.025	validation_1-rmse:240.479
# [1]	validation_0-rmse:222.814	validation_1-rmse:221.173
# [2]	validation_0-rmse:205.575	validation_1-rmse:204.063
# [3]	validation_0-rmse:190.467	validation_1-rmse:188.931
# [4]	validation_0-rmse:177.236	validation_1-rmse:175.83
# [5]	validation_0-rmse:165.797	validation_1-rmse:164.383
# [6]	validation_0-rmse:155.566	validation_1-rmse:154.231
# [7]	validation_0-rmse:146.624	validation_1-rmse:145.386
# [8]	validation_0-rmse:138.655	validation_1-rmse:137.59
# [9]	validation_0-rmse:131.49	validation_1-rmse:130.621
# [10]	validation_0-rmse:125.398	validation_1-rmse:124.688
# [11]	validation_0-rmse:118.57	validation_1-rmse:118.203
# [12]	validation_0-rmse:112.712	validation_1-rmse:112.613
# [13]	validation_0-rmse:105.46	validation_1-rmse:105.865
# [14]	validation_0-rmse:101.209	validation_1-rmse:101.796
# [15]	validation_0-rmse:97.0593	validation_1-rmse:97.9149
# [16]	validation_0-rmse:91.9216	validation_1-rmse:93.0642
# [17]	validation_0-rmse:89.1719	validation_1-rmse:90.3688
# [18]	validation_0-rmse:86.7557	validation_1-rmse:88.0906
# [19]	validation_0-rmse:82.9478	validation_1-rmse:84.527
# [20]	validation_0-rmse:80.8197	validation_1-rmse:82.6187
# [21]	validation_0-rmse:78.6916	validation_1-rmse:80.7038
# [22]	validation_0-rmse:76.535	validation_1-rmse:78.6644
# [23]	validation_0-rmse:72.7327	validation_1-rmse:75.2091
# [24]	validation_0-rmse:70.7264	validation_1-rmse:73.3703
# [25]	validation_0-rmse:67.9877	validation_1-rmse:70.9934
# [26]	validation_0-rmse:66.7764	validation_1-rmse:69.8577
# [27]	validation_0-rmse:64.72	validation_1-rmse:67.946
# [28]	validation_0-rmse:63.8874	validation_1-rmse:67.1669
# [29]	validation_0-rmse:62.6582	validation_1-rmse:66.0732
# [30]	validation_0-rmse:61.9487	validation_1-rmse:65.4108
# [31]	validation_0-rmse:61.052	validation_1-rmse:64.6699
# [32]	validation_0-rmse:59.856	validation_1-rmse:63.6202
# [33]	validation_0-rmse:59.3592	validation_1-rmse:63.1741
# [34]	validation_0-rmse:58.6687	validation_1-rmse:62.511
# [35]	validation_0-rmse:56.9749	validation_1-rmse:60.9724
# [36]	validation_0-rmse:56.3934	validation_1-rmse:60.4343
# [37]	validation_0-rmse:55.7189	validation_1-rmse:59.8064
# [38]	validation_0-rmse:55.3571	validation_1-rmse:59.5838
# [39]	validation_0-rmse:53.9356	validation_1-rmse:58.3509
# [40]	validation_0-rmse:53.5099	validation_1-rmse:57.993
# [41]	validation_0-rmse:52.8346	validation_1-rmse:57.413
# [42]	validation_0-rmse:52.4265	validation_1-rmse:57.0511
# [43]	validation_0-rmse:51.9126	validation_1-rmse:56.6251
# [44]	validation_0-rmse:51.6476	validation_1-rmse:56.3983
# [45]	validation_0-rmse:51.3462	validation_1-rmse:56.169
# [46]	validation_0-rmse:50.335	validation_1-rmse:55.3221
# [47]	validation_0-rmse:50.1585	validation_1-rmse:55.176
# [48]	validation_0-rmse:49.778	validation_1-rmse:54.8771
# [49]	validation_0-rmse:49.5894	validation_1-rmse:54.7289
# [50]	validation_0-rmse:49.2581	validation_1-rmse:54.4745
# [51]	validation_0-rmse:48.3305	validation_1-rmse:53.5913
# [52]	validation_0-rmse:47.9093	validation_1-rmse:53.2166
# [53]	validation_0-rmse:47.6984	validation_1-rmse:53.0755
# [54]	validation_0-rmse:47.46	validation_1-rmse:52.9403
# [55]	validation_0-rmse:47.2575	validation_1-rmse:52.8084
# [56]	validation_0-rmse:46.6324	validation_1-rmse:52.2982
# [57]	validation_0-rmse:46.4256	validation_1-rmse:52.1642
# [58]	validation_0-rmse:46.2462	validation_1-rmse:52.0213
# [59]	validation_0-rmse:46.1184	validation_1-rmse:51.9262
# [60]	validation_0-rmse:45.6403	validation_1-rmse:51.534
# [61]	validation_0-rmse:45.4455	validation_1-rmse:51.3781
# [62]	validation_0-rmse:45.2652	validation_1-rmse:51.2524
# [63]	validation_0-rmse:45.1746	validation_1-rmse:51.1696
# [64]	validation_0-rmse:44.4613	validation_1-rmse:50.5362
# [65]	validation_0-rmse:44.317	validation_1-rmse:50.4338
# [66]	validation_0-rmse:43.9179	validation_1-rmse:50.0375
# [67]	validation_0-rmse:43.8018	validation_1-rmse:49.9805
# [68]	validation_0-rmse:43.6265	validation_1-rmse:49.8504
# [69]	validation_0-rmse:43.4979	validation_1-rmse:49.7385
# [70]	validation_0-rmse:43.4059	validation_1-rmse:49.6714
# [71]	validation_0-rmse:43.2869	validation_1-rmse:49.5945
# [72]	validation_0-rmse:43.215	validation_1-rmse:49.5345
# [73]	validation_0-rmse:43.0995	validation_1-rmse:49.4675
# [74]	validation_0-rmse:42.9508	validation_1-rmse:49.3753
# [75]	validation_0-rmse:42.3179	validation_1-rmse:48.8718
# [76]	validation_0-rmse:42.1975	validation_1-rmse:48.7758
# [77]	validation_0-rmse:41.7255	validation_1-rmse:48.3387
# [78]	validation_0-rmse:41.6475	validation_1-rmse:48.2489
# [79]	validation_0-rmse:41.5605	validation_1-rmse:48.2131
# [80]	validation_0-rmse:41.401	validation_1-rmse:48.0842
# [81]	validation_0-rmse:41.306	validation_1-rmse:48.0292
# [82]	validation_0-rmse:41.1028	validation_1-rmse:47.889
# [83]	validation_0-rmse:41.0099	validation_1-rmse:47.8349
# [84]	validation_0-rmse:40.855	validation_1-rmse:47.7955
# [85]	validation_0-rmse:40.7264	validation_1-rmse:47.714
# [86]	validation_0-rmse:40.4088	validation_1-rmse:47.425
# [87]	validation_0-rmse:40.3509	validation_1-rmse:47.4014
# [88]	validation_0-rmse:40.2749	validation_1-rmse:47.3678
# [89]	validation_0-rmse:39.877	validation_1-rmse:47.0771
# [90]	validation_0-rmse:39.7827	validation_1-rmse:47.0027
# [91]	validation_0-rmse:39.7534	validation_1-rmse:46.9766
# [92]	validation_0-rmse:39.3265	validation_1-rmse:46.6478
# [93]	validation_0-rmse:39.2724	validation_1-rmse:46.6208
# [94]	validation_0-rmse:39.2244	validation_1-rmse:46.6255
# [95]	validation_0-rmse:39.1685	validation_1-rmse:46.5826
# [96]	validation_0-rmse:39.0116	validation_1-rmse:46.4651
# [97]	validation_0-rmse:38.7848	validation_1-rmse:46.2809
# [98]	validation_0-rmse:38.6823	validation_1-rmse:46.214
# [99]	validation_0-rmse:38.4532	validation_1-rmse:46.0403
# [100]	validation_0-rmse:38.4162	validation_1-rmse:46.0346
# [101]	validation_0-rmse:38.3457	validation_1-rmse:46.0174
# [102]	validation_0-rmse:38.1573	validation_1-rmse:45.8544
# [103]	validation_0-rmse:38.0401	validation_1-rmse:45.8059
# [104]	validation_0-rmse:37.8823	validation_1-rmse:45.7135
# [105]	validation_0-rmse:37.7321	validation_1-rmse:45.6125
# [106]	validation_0-rmse:37.579	validation_1-rmse:45.5504
# [107]	validation_0-rmse:37.5483	validation_1-rmse:45.5254
# [108]	validation_0-rmse:37.4542	validation_1-rmse:45.4525
# [109]	validation_0-rmse:37.2885	validation_1-rmse:45.3743
# [110]	validation_0-rmse:37.2143	validation_1-rmse:45.3207
# [111]	validation_0-rmse:37.1375	validation_1-rmse:45.2849
# [112]	validation_0-rmse:37.0506	validation_1-rmse:45.2188
# [113]	validation_0-rmse:36.8214	validation_1-rmse:45.0142
# [114]	validation_0-rmse:36.7345	validation_1-rmse:44.9521
# [115]	validation_0-rmse:36.6682	validation_1-rmse:44.8934
# [116]	validation_0-rmse:36.5661	validation_1-rmse:44.8552
# [117]	validation_0-rmse:36.4181	validation_1-rmse:44.7344
# [118]	validation_0-rmse:36.3356	validation_1-rmse:44.7104
# [119]	validation_0-rmse:36.208	validation_1-rmse:44.691
# [120]	validation_0-rmse:36.1498	validation_1-rmse:44.6562
# [121]	validation_0-rmse:36.1237	validation_1-rmse:44.6397
# [122]	validation_0-rmse:36.0144	validation_1-rmse:44.5872
# [123]	validation_0-rmse:35.9653	validation_1-rmse:44.5195
# [124]	validation_0-rmse:35.9196	validation_1-rmse:44.4835
# [125]	validation_0-rmse:35.9022	validation_1-rmse:44.4738
# [126]	validation_0-rmse:35.8101	validation_1-rmse:44.4493
# [127]	validation_0-rmse:35.7256	validation_1-rmse:44.3897
# [128]	validation_0-rmse:35.6025	validation_1-rmse:44.345
# [129]	validation_0-rmse:35.5632	validation_1-rmse:44.3174
# [130]	validation_0-rmse:35.4866	validation_1-rmse:44.3069
# [131]	validation_0-rmse:35.4061	validation_1-rmse:44.2359
# [132]	validation_0-rmse:35.3536	validation_1-rmse:44.2071
# [133]	validation_0-rmse:35.3182	validation_1-rmse:44.208
# [134]	validation_0-rmse:35.28	validation_1-rmse:44.1939
# [135]	validation_0-rmse:35.257	validation_1-rmse:44.1878
# [136]	validation_0-rmse:35.2195	validation_1-rmse:44.1722
# [137]	validation_0-rmse:35.1672	validation_1-rmse:44.137
# [138]	validation_0-rmse:35.0985	validation_1-rmse:44.0935
# [139]	validation_0-rmse:35.0623	validation_1-rmse:44.0586
# [140]	validation_0-rmse:35.0458	validation_1-rmse:44.0519
# [141]	validation_0-rmse:35.0304	validation_1-rmse:44.042
# [142]	validation_0-rmse:34.9691	validation_1-rmse:44.0269
# [143]	validation_0-rmse:34.9399	validation_1-rmse:44.0023
# [144]	validation_0-rmse:34.8966	validation_1-rmse:43.9539
# [145]	validation_0-rmse:34.8406	validation_1-rmse:43.9477
# [146]	validation_0-rmse:34.7385	validation_1-rmse:43.8967
# [147]	validation_0-rmse:34.7118	validation_1-rmse:43.8866
# [148]	validation_0-rmse:34.6408	validation_1-rmse:43.8734
# [149]	validation_0-rmse:34.5258	validation_1-rmse:43.8091
# XGBRegressor(max_depth=5, n_estimators=150)

# %%
eval_result = regressor.evals_result()

# %%
training_rounds = range(len(eval_result['validation_0']['rmse']))

# %%
print(training_rounds)
# Out:
# range(0, 150)

# %%
plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.grid(True)
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
xgb.plot_importance(regressor)
plt.show()

# %%
# Verify Quality using Validation dataset
# Compare actual vs predicted performance with dataset not seen by the model before
df = pd.read_csv(validation_file,names=columns)

# %%
df.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0    443       3        0           1        2  28.70  33.335        79
# 1    387       2        0           0        1  32.80  37.880        55
# 2      2       1        0           1        1  14.76  16.665        40
# 3     48       1        0           1        1   9.02   9.090        47
# 4     55       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
df.shape
# Out:
# (3266, 14)

# %%
X_test = df.iloc[:,1:]
print(X_test[:5])
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       3        0           1        2  28.70  33.335        79    12.9980
# 1       2        0           0        1  32.80  37.880        55    12.9980
# 2       1        0           1        1  14.76  16.665        40    19.9995
# 3       1        0           1        1   9.02   9.090        47    36.9974
# 4       4        0           0        1  10.66  15.150        87     0.0000
#
#    year  month  day  dayofweek  hour
# 0  2011      7    7          3     8
# 1  2011      6   11          5    13
# 2  2011      2   14          0     2
# 3  2011      2    8          1    10
# 4  2011     12    4          6     8

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([448.20044  , 384.77954  ,  -3.0475748,  25.569548 ,  85.49567  ],
#       dtype=float32)

# %%
df['count_predicted'] = result

# %%
df.head()
# Out:
#    count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0    443       3        0           1        2  28.70  33.335        79
# 1    387       2        0           0        1  32.80  37.880        55
# 2      2       1        0           1        1  14.76  16.665        40
# 3     48       1        0           1        1   9.02   9.090        47
# 4     55       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour  count_predicted
# 0    12.9980  2011      7    7          3     8       448.200439
# 1    12.9980  2011      6   11          5    13       384.779541
# 2    19.9995  2011      2   14          0     2        -3.047575
# 3    36.9974  2011      2    8          1    10        25.569548
# 4     0.0000  2011     12    4          6     8        85.495667

# %%
# Negative Values are predicted
df['count_predicted'].describe()
# Out:
# count    3266.000000
# mean      190.530060
# std       170.386520
# min       -81.801498
# 25%        41.860569
# 50%       153.973351
# 75%       287.010712
# max       870.350220
# Name: count_predicted, dtype: float64

# %%
df[df['count_predicted'] < 0]
# Out:
#       count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 2         2       1        0           1        1  14.76  16.665        40
# 35        3       2        0           1        1  19.68  23.485        63
# 100       1       1        0           1        1   6.56   6.060        31
# 133      20       1        0           0        3   6.56   9.090        93
# 158      45       1        0           0        2  12.30  13.635       100
# ...     ...     ...      ...         ...      ...    ...     ...       ...
# 3066      3       1        0           1        1   4.92   6.060        50
# 3071      6       1        0           0        1   3.28   4.545        53
# 3093      4       1        0           1        1   5.74   6.820        46
# 3118      2       1        0           1        2  10.66  13.635        93
# 3121      1       1        0           1        1   5.74   7.575        86
#
#       windspeed  year  month  day  dayofweek  hour  count_predicted
# 2       19.9995  2011      2   14          0     2        -3.047575
# 35      15.0013  2011      4   19          1     3        -0.686532
# 100     32.9975  2011      3    3          3     4       -11.336152
# 133      7.0015  2011      1    8          5     9        -5.350302
# 158     19.9995  2011      3    5          5     8        -8.830898
# ...         ...   ...    ...  ...        ...   ...              ...
# 3066    15.0013  2011      1   10          0     2        -7.941698
# 3071    12.9980  2011      1    9          6     7       -58.085678
# 3093    12.9980  2012      2   13          0     2        -5.543156
# 3118     7.0015  2011      2    8          1     2        -1.763405
# 3121     8.9981  2011      1   12          2     2        -4.338954
#
# [84 rows x 15 columns]

# %%
df['count_predicted'].hist()
plt.title('Predicted Count Histogram')
plt.show()

# %%
def adjust_count(x):
    if x < 0:
        return 0
    else:
        return x

# %%
df['count_predicted'] = df['count_predicted'].map(adjust_count)

# %%
df[df['count_predicted'] < 0]
# Out:
# Empty DataFrame
# Columns: [count, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, year, month, day, dayofweek, hour, count_predicted]
# Index: []

# %%
# Actual Vs Predicted
plt.plot(df['count'], label='Actual')
plt.plot(df['count_predicted'],label='Predicted')
plt.xlabel('Sample')
plt.ylabel('Count')
plt.xlim([100,150])
plt.title('Validation Dataset - Predicted Vs. Actual')
plt.legend()
plt.show()

# %%
# Over prediction and Under Prediction needs to be balanced
# Training Data Residuals
residuals = (df['count'] - df['count_predicted'])

plt.hist(residuals)
plt.grid(True)
plt.xlabel('Actual - Predicted')
plt.ylabel('Count')
plt.title('Residuals Distribution')
plt.axvline(color='r')
plt.show()

# %%
value_counts = (residuals > 0).value_counts(sort=False)
print(' Under Estimation: {0:0.2f}'.format(value_counts[True]/len(residuals)))
print(' Over  Estimation: {0:0.2f}'.format(value_counts[False]/len(residuals)))
# Out:
#  Under Estimation: 0.48
#  Over  Estimation: 0.52

# %%
print("RMSE: {0:0.2f}".format(mean_squared_error(df['count'],df['count_predicted'])**.5))
# Out:
# RMSE: 43.68

# %%
# RMSlE - Root Mean Squared Log Error
# RMSLE Metric is used by Kaggle for this competition

# RMSE Cost Function - Magnitude of difference matters

# RMSLE cost function - "Only Percentage difference matters"

# Reference:Katerina Malahova, Khor SoonHin 
# https://www.slideshare.net/KhorSoonHin/rmsle-cost-function
def compute_rmsle(y_true, y_pred):
    if type(y_true) != np.ndarray:
        y_true = np.array(y_true)
        
    if type(y_pred) != np.ndarray:
        y_pred = np.array(y_pred)
     
    return(np.average((np.log1p(y_pred) - np.log1p(y_true))**2)**.5)

# %%
print('RMSLE')
print(compute_rmsle(100,50),
      compute_rmsle(1000,500),
      compute_rmsle(10000,5000))
# Out:
# RMSLE
# 0.683294884116934 0.6921486782303559 0.6930471955576127

# %%
print('RMSLE')
print(compute_rmsle(100,25),
      compute_rmsle(1000,250),
      compute_rmsle(10000,2500))
# Out:
# RMSLE
# 1.3570239788197775 1.383301840183437 1.3859944360988976

# %%
print('RMSE')
print(mean_squared_error([100],[50])**.5,
      mean_squared_error([1000],[500])**.5, 
      mean_squared_error([10000],[5000])**.5)
# Out:
# RMSE
# 50.0 500.0 5000.0

# %%
print('RMSE')
print(mean_squared_error([100],[25])**.5,
      mean_squared_error([1000],[250])**.5, 
      mean_squared_error([10000],[2500])**.5)
# Out:
# RMSE
# 75.0 750.0 7500.0

# %%
print("RMSLE: {0}".format(compute_rmsle(df['count'],df['count_predicted'])))
# Out:
# RMSLE: 0.49787719339339304

# %%
# Prepare Data for Submission to Kaggle
df_test = pd.read_csv(test_file,parse_dates=['datetime'])

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour
# 0        56    26.0027  2011      1   20          3     0
# 1        56     0.0000  2011      1   20          3     1
# 2        56     0.0000  2011      1   20          3     2
# 3        56    11.0014  2011      1   20          3     3
# 4        56    11.0014  2011      1   20          3     4

# %%
X_test =  df_test.iloc[:,1:] # Exclude datetime for prediction

# %%
X_test.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    year  month  day  dayofweek  hour
# 0  2011      1   20          3     0
# 1  2011      1   20          3     1
# 2  2011      1   20          3     2
# 3  2011      1   20          3     3
# 4  2011      1   20          3     4

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([10.033908 , -1.0149912, -5.805891 , -4.739464 , -4.739464 ],
#       dtype=float32)

# %%
df_test["count"] = result

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour      count
# 0        56    26.0027  2011      1   20          3     0  10.033908
# 1        56     0.0000  2011      1   20          3     1  -1.014991
# 2        56     0.0000  2011      1   20          3     2  -5.805891
# 3        56    11.0014  2011      1   20          3     3  -4.739464
# 4        56    11.0014  2011      1   20          3     4  -4.739464

# %%
df_test[df_test["count"] < 0]
# Out:
#                 datetime  season  holiday  workingday  weather   temp   atemp  \
# 1    2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2    2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3    2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4    2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 25   2011-01-21 01:00:00       1        0           1        2   9.84  11.365
# ...                  ...     ...      ...         ...      ...    ...     ...
# 5624 2012-09-28 04:00:00       4        0           1        3  22.96  26.515
# 5906 2012-10-28 22:00:00       4        0           0        3  18.04  21.970
# 5907 2012-10-28 23:00:00       4        0           0        3  17.22  21.210
# 6230 2012-12-20 23:00:00       4        0           1        3  16.40  20.455
# 6372 2012-12-26 23:00:00       1        0           1        3  10.66  11.365
#
#       humidity  windspeed  year  month  day  dayofweek  hour      count
# 1           56     0.0000  2011      1   20          3     1  -1.014991
# 2           56     0.0000  2011      1   20          3     2  -5.805891
# 3           56    11.0014  2011      1   20          3     3  -4.739464
# 4           56    11.0014  2011      1   20          3     4  -4.739464
# 25          70    16.9979  2011      1   21          4     1  -0.198152
# ...        ...        ...   ...    ...  ...        ...   ...        ...
# 5624        88     7.0015  2012      9   28          4     4  -3.935430
# 5906        88    23.9994  2012     10   28          6    22 -16.126238
# 5907        94    23.9994  2012     10   28          6    23 -22.221630
# 6230        82    19.9995  2012     12   20          3    23  -0.718980
# 6372        87    19.9995  2012     12   26          2    23 -13.475777
#
# [231 rows x 15 columns]

# %%
df_test["count"] = df_test["count"].map(adjust_count)

# %%
df_test[['datetime','count']].to_csv('predicted_count.csv',index=False)

# %%
# RMSLE (Kaggle) Score
# Test 1: 0.62
